# %%
print("Hey, Universe!")

# %% [markdown]
# My name is Whitney Abernathy. I love sports, food, and am a sneakerhead. I am excited to learn about data analysis and how I can translate these skills with the statistical data in the sports world. Learning new things is not easy, but with the help of the mentors I'm ready to push myself to new heights.
